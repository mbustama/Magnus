# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib import pyplot

import os, sys
sys.path.append(os.path.split(os.getcwd())[0]+'/src/')
# cwd = 
# sys.path += ['../magnus']

# from magnus import globaldefs

# import oscprob
# import oscprobstd
# import hamiltonians2nu
# import matter
# import globaldefs as gd

# import magnus
import magnus.magnus as magnus
import magnus.oscprob.oscprob as oscprob
import magnus.oscprob.oscprobstd as oscprobstd
import magnus.hamiltonians.hamiltonians2nu as hamiltonians2nu
import magnus.hamiltonians.hamiltonians3nu as hamiltonians3nu
import magnus.matter as matter
import magnus.globaldefs as gd

# %%
print(magnus.__name__)
print(magnus.__all__)
# Out:
# magnus.magnus
# ['B', 'Optional', 'compute_magnus_terms', 'f1', 'f2', 'magnus', 'magnus_expansion', 'name', 'np', 'sp', 'sys', 'valid_integration_methods']

# %%
# print(magnus.globaldefs.CONV_KM_TO_INV_EV)
print(gd.CONV_KM_TO_INV_EV)
print(gd.__name__)
# Out:
# 5067730000.0
# magnus.globaldefs

# %%
print(sys.path)
# print(magnus.globaldefs.GF)
# Out:
# ['/home/mbustamante/Research/magnus/notebooks', '/home/mbustamante/anaconda3/envs/py310/lib/python39.zip', '/home/mbustamante/anaconda3/envs/py310/lib/python3.9', '/home/mbustamante/anaconda3/envs/py310/lib/python3.9/lib-dynload', '', '/home/mbustamante/.local/lib/python3.9/site-packages', '/home/mbustamante/anaconda3/envs/py310/lib/python3.9/site-packages', '/home/mbustamante/Research/magnus/src/', '/home/mbustamante/Research/magnus/src/', '/home/mbustamante/Research/magnus/src/']

# %%
os.path.split(os.getcwd())[0]+'/magnus/'
# Out:
# '/home/mbustamante/Research/magnus/magnus/'
